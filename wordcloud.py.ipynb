# %%
import pathlib
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image 
# %matplotlib inline

# %%
path = pathlib.Path.cwd()/"Romeo and Juliet.txt"
print(path)
# Out:
# C:\Users\ZhenP\OneDrive\Desktop\wordcloud\Romeo and Juliet.txt

# %%
text = path.read_text()
wordcloud = WordCloud().generate(text)

plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off")
plt.savefig("Romeo and Juliet.png", dpi = 1000, facecolor = "w", format= "png")
plt.show()

# %%
mask = np.array(Image.open("shakespeare-people-page.jpg"))
New_word_cloud = WordCloud(stopwords = stopwords, background_color = "w", max_words = 1000, mask=mask).generate
image_colors = ImageColorGenerator(mask)
plt.figure(figsize = [10,10])
plt.imshow(New_word_cloud.recolor(color_func=image_colors), interpolation = "bilinear")
plt.axis("off")
plt.savefig("Romeo and Juliet2.png", dpi = 600, facecolor = "w", format="png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-203a2a812640> in <module>
#       3 image_colors = ImageColorGenerator(mask)
#       4 plt.figure(figsize = [10,10])
# ----> 5 plt.imshow(New_word_cloud.recolor(color_func=image_colors), interpolation = "bilinear")
#       6 plt.axis("off")
#       7 plt.savefig("Romeo and Juliet2.png", dpi = 600, facecolor = "w", format="png")
#
# AttributeError: 'function' object has no attribute 'recolor'
